# %%
dbutils.help()

# %%
dbutils.fs.help()

# %%
dbutils.fs.ls("dbfs:/Volumes/retail/schema_retail/volume_retail/customer")

# %%
# recursively create teh directory if not exists
dirlst = ["01","02","03","04","05","06","07","08","09","10","11","12"]

for i in dirlst:
    # print(i)
    dbutils.fs.mkdirs(f"dbfs:/Volumes/retail/schema_retail/volume_retail/customer/2026/{i}")
    
                #   "dbfs:/Volumes/retail/schema_retail/volume_retail/customer/2026/02","dbfs:/Volumes/retail/schema_retail/volume_retail/customer/2026/03")

# %%
dbutils.fs.ls("dbfs:/Volumes/retail/schema_retail/volume_retail/customer/2026/")

# %%
path='dbfs:/Volumes/retail/schema_retail/volume_retail/customer/2026/01/'
dbutils.fs.put(f"{path}01_file.txt","my text is related to 01",True)

# %%
path='dbfs:/Volumes/retail/schema_retail/volume_retail/customer/2026/01/'
fileinfo =dbutils.fs.ls(path)

# %%
for i in fileinfo:
    # print(i.path)
    dbutils.fs.head(i.path)

# %%
dbutils.widgets.dropdown("dropdown_widget","Senthil",["Senthil","Balaji","Arun"],"Select your name")
aspirant_name_chosen=dbutils.widgets.get("dropdown_widget")
print("Good morning",aspirant_name_chosen)

# %%
dbutils.widgets.multiselect("multiselect_widget","wd36",["wd32","we43","we45","wd36"],"Select your team name")
all_batches=dbutils.widgets.get("multiselect_widget")
print(all_batches)
all_batches_lst=all_batches.split(",")
for i in all_batches_lst:
    print(f"hello team {i}")
#print("You have chosen the team name as",all_batches)

# %%
dbutils.widgets.multiselect("multiselect_widget11","wd36",["wd32","we43","we45","wd36"],"Select your team name")
all_batches=dbutils.widgets.get("multiselect_widget11")
print(all_batches)
all_batches_lst=all_batches.split(",")
for i in all_batches_lst:
    print(f"hello team {i}")
#print("You have chosen the team name as",all_batches)

# %%
#Interview question- how to access some value from the given string
fullname="mohamed kader irfan"
fname=fullname.split(" ")[0]
lname=fullname.split(" ")[-1]
lname=fullname.split(" ")[1]
print(fname, 'and', lname)

# %%
dict_all_widgets=dbutils.widgets.getAll()
print(dict_all_widgets)
