# %% [markdown]
# #Mobile operating system usage metrix
# ##Created By : $${\color{blue}Stracy}$$

# %% [markdown]
# #####Task2: Create a volume namely usage_metrics using sql magic command %sql

# %%
child_return_value=dbutils.notebook.run(
                                        "/Workspace/Users/anto2003.sfn@gmail.com/databricks-code-repo/4_child_nb_dataload",180)

# %run "/Workspace/Users/anto2003.sfn@gmail.com/databricks-code-repo/4_child_nb_dataload"

# %%
# dbutils.fs.ls("/Volumes/workspace/db_schema_sales/ingestion_volume/source/mobile_os_usage.csv")

# %%
# dbutils.fs.head("/Volumes/workspace/db_schema_sales/ingestion_volume/source/mobile_os_usage.csv")

# %%
# df = spark.read.csv("/Volumes/workspace/db_schema_sales/ingestion_volume/source/mobile_os_usage.csv")
