# %%
from pyspark.sql import SparkSession

spark = SparkSession.builder.appName("CSVMergeSchema").getOrCreate()

# Path to a directory containing multiple CSVs with different columns
path = "dbfs:///Volumes/telecom_catalog_assign/landing_zone/landing_vol/customer/custo*.csv"

# Spark 3.x+ automatically merges schemas for CSVs when reading a directory
# provided 'header' is true and 'inferSchema' is true.
df = spark.read.format("csv").load(path)
    # .option("header", "true") \
        
    # .option("inferSchema", "true") \
    

df.show()
df.printSchema()
