# %% [markdown]
# ###Enterprise Fleet Analytics Pipeline: Focuses on the business outcome (analytics) and the domain (fleet/logistics).

# %%
import json
json_nbook_out = dbutils.notebook.run("/Workspace/Users/anto2003.sfn@gmail.com/databricks-code-repo/Learning/retailLogistics_usecase/pyspark/1_RetailConfig",120,{"catalog":"retail","schema":"logistics"})
# print(json_nbook_out)
json = json.loads(json_nbook_out)
print(json["catalog"])

# %%
# %run /Workspace/Users/anto2003.sfn@gmail.com/databricks-code-repo/Learning/retailLogistics_usecase/pyspark/2_Retail_utility

# %%
catalog = json["catalog"]
schema = json["schema"]
source = json["source"]
bronze = json["bronze"]
silver = json["silver"]
gold = json["gold"]

# %%
spark= getSparkSession()
# print(s)

# %%
df1 = read_file(spark,'csv', \
                f"{source}/logistics_source1.txt", \
                     header=True,inferSchema=True,sep=",")


df2 = read_file(spark,'csv', \
                f"{source}/logistics_source2.txt", \
                     header=True,inferSchema=True,sep=",")


display(df1)
display(df2)

# %%
j_df = join_df(df1,df2,"left_outer")
display(j_df)

# %%
m_df = merge_df(df1,df2)
m_df.show()
m_df.printSchema()

# %%
#Geo tagging data read operations
geo_df=read_file(spark,"csv",f"{source}/Master_City_List.csv",True,False)
geo_df.show()

# %%
df1.printSchema()
df2.printSchema()
df.printSchema()

# %%
df.where("hub_location is not null").count()

# %%
write_file(df,"overwrite","delta" ,f"{bronze}/logistics_cust")

# %%
dbutils.fs.ls (f"{bronze}/logistics_cust/")

# %%
from pyspark.sql import functions as F
df2.groupBy(F.col("vehicle_type"),F.col("role")).agg(F.count("vehicle_type").alias("kount")).show()
# df2.where("vehicle_type is NULL").count()
# .agg(F.col(F.count()).alias("cnt")).show()

# %%
df2.where("vehicle_type is NULL").count()

# %%
df.where ("vehicle_type is not NULL").groupBy(F.col("vehicle_type"),F.col("role")).agg(F.count("*").alias("kount")).show()

# %%
df_json = read_file(spark, \
                    "json",f"{source}/logistics_shipment_detail_3000.json")
# display(df_json)
df_json.show()

# %%
# dbutils.widgets.text("catalog","")
# CATALOG=dbutils.widgets.get("catalog").strip()
# dbutils.widgets.text("schema","")
# SCHEMA=dbutils.widgets.get("schema").strip()

# %% [markdown]
# ###Getting the Parameters

# %%
import json

# 1. Retrieve the string (Default to an empty JSON object string)
pay_load = dbutils.jobs.taskValues.get(taskKey="Reading_config", key="payload", debugValue="{}")

print('pay_load', pay_load)

# %% [markdown]
# ###Setting generic configurations

# %%
print(CATALOG)

# %%
import json

dump = dbutils.notebook.run("/Workspace/Users/anto2003.sfn@gmail.com/databricks-code-repo/Learning/retailLogistics_usecase/pyspark/1_RetailConfig", 120, {"catalog": CATALOG, "schema": SCHEMA})
print(dump)
config = json.loads(dump)

print(config["source"])
print(config["datalake"])
print(config["bronze"])
