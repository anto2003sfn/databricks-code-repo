# %%
dbutils.widgets.text("catalog","retail")
dbutils.widgets.text("schema","schema_retail")

# %%
# Set default catalog and schema
catalog = dbutils.widgets.get("catalog").strip()
schema = dbutils.widgets.get("schema").strip()
# spark.sql(f"USE CATALOG {catalog}")
# spark.sql(f"USE SCHEMA {schema}")
print(f"{catalog}.{schema}")

# %%
# spark.sql('use f"""{catalog}.{schema}""";')
df = spark.sql(f"""select * from {catalog}.{schema}.tblsales""")
df.write.mode("append").saveAsTable(f"""{catalog}.{schema}.tblsales_dab""")
# df.count()

# %%
display(df)

# %%
# %sql
select * from retail.schema_retail.bronze_products;

# %%
# %sql
select * from retail.schema_retail.bronze_purchase where product_id='1'
