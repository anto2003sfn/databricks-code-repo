# %%
from pyspark.sql import SparkSession
spark = SparkSession.builder.appName("BranchingTechniques").getOrCreate()
cnt = spark.read.table("cat_sales.default.account").count()
cnt=0
print(cnt)

# display(spark.read.table("cat_sales.default.account"))

# %%
dbutils.jobs.taskValues.set(key = "row_count", value=cnt)
