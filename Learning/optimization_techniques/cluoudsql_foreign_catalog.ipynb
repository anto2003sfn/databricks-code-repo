# %%
# %sql
CREATE CONNECTION mysql_connectionworking1
TYPE mysql
OPTIONS (
  host '152.58.71.34.bc.googleusercontent.com',
  port '3306',
  user 'root',
  password 'Inceptez@123',
  trustServerCertificate 'true'
);

CREATE FOREIGN CATALOG cloudsql_foreign_catalog1
USING CONNECTION mysql_connectionworking1;

# %%
# %sql
select * from cloudsql_foreign_catalog1.testdb.tbl1;
