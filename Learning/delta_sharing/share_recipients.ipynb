# %%
# %sql
create share my_share;

# %%
# %sql

drop table if exists retail.logistics.dual;

# %%
# %sql
create table if not exists retail.logistics.dual(X varchar(10))

# %%
df = spark.sql("describe detail retail.logistics.dual")
display(df)

# %%
# %sql
alter share my_share add retail.logistics.dual;

# %%
# %sql
-- create recipient my_recipient;
insert into retail.logistics.dual (X) values ('X')

# %%
# %sql
select * 
-- delete 
from retail.logistics.dual 
-- where X='example';

# %%
# %sql
-- CREATE RECIPIENT external_partner;

use catalog retail;

# %%
# %sql 
show grants on catalog retail;

# %%
# %sql 
show grants `b4a43a2c-4074-481f-a93e-c2e90fba220b` on catalog retail;

# %%
# %sql
create recipient my_receipient;

# %%
# %sql
-- create role test_role;
