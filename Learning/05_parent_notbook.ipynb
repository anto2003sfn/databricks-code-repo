# %%
ABC="Parent->Child"

# %%
def Hi(name):
    print("Hello",name)

# %%
def greeting():
    print("wow you are awesome")

# %%
def greeting(name="Anthony"):
    print(f"wow {name} you are awesome")

# %%
class SampleConstructor:
    def calc(self,val=0):
        print("int", val)
    def calc(self,val=0.0):
        print("float", val)
    def calc(self,val="stracy"):
        print("string", val)
