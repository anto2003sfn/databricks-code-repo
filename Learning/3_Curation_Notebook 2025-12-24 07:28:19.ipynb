# %%
from pyspark.sql import SparkSession
from pyspark.sql.types import *

# %%
spark = SparkSession.builder.appName("Curation").getOrCreate();
raw_df = spark.read.csv("/Volumes/telecom_catalog_assign/landing_zone/landing_vol/customer/custsmodified")
# DBTITLE 1,Read CSV
# csv_df = spark.read.csv("/FileStore/tables/employees.csv", header=True

display(raw_df)

# %%
raw_df.columns

# %%
raw_df.printSchema()

# %%
raw_df.schema

# %%
struct_schema = StructType([StructField('cust_id', StringType(), True), StructField('fname', StringType(), True), StructField('lname', StringType(), True), StructField('age', StringType(), True), StructField('prof', StringType(), True)])

# %%
df = spark.read.schema(struct_schema).csv("/Volumes/telecom_catalog_assign/landing_zone/landing_vol/customer/custsmodified")

# %%
df.show()

# %%
df.describe

# %%
display(df.describe())

# %%
display(df.summary())
# df.describe().show()

# %%
df.distinct().count()

# %%
df1 = df.unionByName(df)

# %%
display(df1)

# %%
# raw_df = spark.read.csv("/Volumes/telecom_catalog_assign/landing_zone/landing_vol/customer/custsmodified")

from pyspark.sql.types import *

schema = StructType([
     StructField("id", StringType(), True),
    StructField("fname", StringType(), True),
    StructField("lname", StringType(), True),
    StructField("age", StringType(), True),
    StructField("prof", StringType(), True),
    # StructField("_corrupt_record", StringType(), True) # Special column
])

df = (spark.read
      .format("csv")
      .option("header", "true")
      .option("mode", "PERMISSIVE")
    #   .option("columnNameOfCorruptRecord", "_corrupt_record")
      .schema(schema)
      .load("dbfs:/Volumes/telecom_catalog_assign/landing_zone/landing_vol/customer/custsmodified"))

# %%
# df.filter("_corrupt_record is not null").show(truncate=False)

df.show(truncate=False)

# %%
df1 =df.dropna()


df2 =df.na.drop()

# %%
print(df1.count())
print(df2.count())

# %%
df1.show()
