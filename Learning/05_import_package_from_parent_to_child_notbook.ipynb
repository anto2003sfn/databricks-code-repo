# %% [markdown]
# ####magic run like include in c & C++ by defining all the variables and definitions/methods
# ####ideal for modurlarizing

# %%
# %run /Workspace/Users/anto2003.sfn@gmail.com/databricks-code-repo/Learning/05_parent_notbook

# %% [markdown]
# dbutils.notebook.run("/Users/anto2003.sfn@gmail.com/databricks-code-repo/Learning/parent_notbook", 60)<br>
# it is running as separate job<br>
# mainting the isolation<br>
# defintions are not shared<br>
# passing/retruning parameters<br>

# %%
Hi("Stracy Savari")
"""
Definition overloading concept

"""
greeting()
greeting("Stracy Savari Anthony")
greeting("Joe")
greeting("Kevin")

# %%
cons = SampleConstructor()
cons.calc(int('10'))
cons.calc(10.5)
cons.calc("stracy")

# %%
print(ABC)

# %%
# df = spark.readStream.format("pubsub").option("pubsub.subscrtion","project/myrpoject/subscritipn/retailSubs").load()

# %%
# pdf = df.select(F.col("payload").cast("stirng"), "eventts current_timestamp()" ).alias("data").select("data.*").withWatermark("eventts","10 minutes")

# %%
# pdf.writeStream.foreachBatch()

# %%
dbutils.notebook.jvm
