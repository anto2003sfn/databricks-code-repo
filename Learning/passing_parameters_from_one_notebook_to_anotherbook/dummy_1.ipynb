# %%
# Define the input parameter
dbutils.widgets.text("catalog", "dummy_catalog")
dbutils.widgets.text("schema", "dummy_schema")

# Fetch the value passed from the parent
catalog = dbutils.widgets.get("catalog")
schema = dbutils.widgets.get("schema")
print(f"Processing data for User ID: {catalog}")
print(f"Processing data for User ID: {schema}")

# Optional: Return a value to the parent
dbutils.notebook.exit(f"Success: Processed {catalog}.{schema}")
