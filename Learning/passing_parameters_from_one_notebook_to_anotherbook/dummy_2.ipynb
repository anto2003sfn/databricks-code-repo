# %%
# Define the parameters to pass
params = {"catalog": "retail","schema": "logistics"}

# Run the notebook
result = dbutils.notebook.run("/Workspace/Users/anto2003.sfn@gmail.com/dummy_1", 60, params)

# Print the exit message from the child
print(result)
