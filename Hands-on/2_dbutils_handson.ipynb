# %% [markdown]
# #Hands on for dbutils command

# %%
dbutils.help()

# %%
dbutils.widgets.help()
# dbutils.fs.help()
# dbutils.fs.ls("dbfs:/")

# %%
dbutils.widgets.combobox("dbname", "default", ["default", "Sales","Finance","Marketing"])
dbselected = dbutils.widgets.get("dbname")
print("Hi selected db is " ,dbselected)

# %%
 dbutils.widgets.multiselect("multiselect","wd36",["wd32","we43","we45","wd36"],"Team names multiselect")

# %%
lst = dbutils.widgets.get("multiselect")
print(lst)

# %%
child_return_value=dbutils.notebook.run("/Workspace/Users/anto2003.sfn@gmail.com/databricks-code-repo/dbutils_handson_child_run",180,
                                        {"param1":lst})
