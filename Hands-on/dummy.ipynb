# %% [markdown]
# #####Data Bricks Fundamentals
# 1. Catalog creation
# 2. Database/schema creation
# 3. Volume creation
# 4. Directory creation
# 5. Upload the files via manual or through databbricks command

# %%
# %sh ls

# %%
# %sh echo "Hi Guys"

# %%
import datetime
dt = datetime.date.isoformat(datetime.date.today())
print(dt)

# %%
spark.read.options(header='true', inferSchema='true').parquet('/FileStore/tables/2019-01-01.parquet').write.mode('overwrite').saveAsTable('bronze')
# csv('/FileStore/tables/2019-01-01.csv').write.mode('overwrite').saveAsTable('bronze')
