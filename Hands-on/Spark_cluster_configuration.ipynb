# %%
# Check executor configuration (serverless compatible)
cores_per_executor = spark.conf.get("spark.executor.cores", None)
total_memory = spark.conf.get("spark.executor.memory", None)

print(f"Cores per Executor: {cores_per_executor}")
print(f"Memory per Executor: {total_memory}")
