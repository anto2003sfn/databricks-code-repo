# %%
# %sql
-- drop database if exists db_schema_mobile;
-- create database if not exists db_schema_mobile;
-- drop volume if exists workspace.db_schema_mobile.usage_metrics;
create volume if not exists workspace.db_schema_sales.usage_metrics;
-- drop table db_schema_mobile.usage_metrics;
-- select * from db_schema_mobile.usage_metrics

# %%
import requests
req = requests.get("https://public.tableau.com/app/sample-data/mobile_os_usage.csv")
# print(req.text )

# %%
dbutils.fs.put("/Volumes/workspace/db_schema_sales/usage_metrics/mobile_os_usage.csv",req.text,overwrite=True)

# %%
# %sql
# drop database if exists db_schema_mobile;
# create database if not exists db_schema_mobile;
# drop volume if exists workspace.db_schema_mobile.usage_metrics;
# create volume if not exists workspace.db_schema_mobile.usage_metrics;
# delete from db_schema_mobile.usage_metrics;
# -- select * from db_schema_mobile.usage_metrics

# %%
dbutils.fs.ls("/Volumes/workspace/db_schema_sales/usage_metrics/mobile_os_usage.csv")

# %%
# %sql drop table if exists db_schema_sales.mobile_os_usage;

# %%
df = spark.read.csv("/Volumes/workspace/db_schema_sales/usage_metrics/mobile_os_usage.csv",header=True).toDF ("date","mobile_ops_sys","percentile")
df.show(5)
# spark.sql
df.write.saveAsTable("db_schema_sales.mobile_os_usage")

# %%
# %sql
select * from db_schema_sales.mobile_os_usage;

# %%
# %python
spark.sql("select * from db_schema_sales.mobile_os_usage").show(100

)

# %%
original_text = "Good to see you in databricks learning."

def toUpper(input_string):
  uppercase_string = input_string.upper()
  return uppercase_string

result = toUpper(original_text)
print(f"Original: {original_text}")
print(f"Uppercase: {result}") 
# Output: Uppercase: HELLO WORLD! THIS IS A TEST.

# %%
# %pip install pandas

# %%
import pandas as pd
pdf = pd.read_csv("/Volumes/workspace/db_schema_sales/usage_metrics/mobile_os_usage.csv",header=0)

# %%
pdf.head()
# pdf["Percent of Usage"] = pdf["Percent of Usage"].astype(float)

# %%
# %python pdf.describe

# %%
# %sh echo "Magic commands tasks completed"
