# %% [markdown]
# #####Data Bricks Fundamentals
# 1. Catalog creation
# 2. Database/schema creation
# 3. Volume creation
# 4. Directory creation
# 5. Upload the files via manual or through databbricks command

# %%
# %sh ls

# %%
# %sh echo "Hi Guys"

# %%
# %sql

-- create catalog if not exists dummy_cat;
drop catalog if exists dummy_cat cascade;

# %%
dbutils.fs.ls
